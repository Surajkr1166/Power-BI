# %% [markdown]
# <a href="https://colab.research.google.com/github/Surajkr1166/Power-BI/blob/main/Naive_bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the required libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from google.colab import files
from sklearn.model_selection import train_test_split # Import the train_test_split function

# Uploading the dataset
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b3e7494d-1d63-4a8b-8197-fc82ac91671c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b3e7494d-1d63-4a8b-8197-fc82ac91671c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Reading the dataset
df = pd.read_csv("try.csv")
print(df)

# Checking for any additional variations of the dataset
df3 = pd.read_csv("try.csv")
print(df3)

df4 = pd.read_csv("try.csv")
print(df4)

# Extracting the target column 'Outcome'
df5 = pd.read_csv("try.csv", usecols=['Outcome'])
print(df5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Visualizing the correlation matrix using heatmap
plt.figure(figsize=(13, 10))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="Set2")
# Out:
# <Axes: >

# %%
# Splitting features (X) and target (Y)
X = df.drop(columns=['Outcome'])  # Drop the 'Outcome' column for features
Y = df['Outcome']  # Extract the target column

# %%
# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.30, random_state=0)

# Feature scaling (optional for Naive Bayes but good practice)
scale = StandardScaler()
X_train = scale.fit_transform(X_train)
X_test = scale.transform(X_test)

# %%
# Initialize the Naive Bayes Classifier
clf = GaussianNB()

# Train the Naive Bayes Classifier
clf.fit(X_train, Y_train)

# Make predictions
y_test_pred = clf.predict(X_test)
y_train_pred = clf.predict(X_train)

# Confusion matrix for training and testing sets
cm_train = confusion_matrix(Y_train, y_train_pred)
cm_test = confusion_matrix(Y_test, y_test_pred)

# %%
# Output confusion matrices
print("Confusion Matrix - Training Data:\n", cm_train)
print("Confusion Matrix - Test Data:\n", cm_test)

# Calculate accuracy
train_accuracy = accuracy_score(Y_train, y_train_pred)
test_accuracy = accuracy_score(Y_test, y_test_pred)

# Output the accuracy
print("Accuracy on the training set: {:.3f}".format(train_accuracy))
print("Accuracy on the test set: {:.3f}".format(test_accuracy))

# Classification report for the test set
print("The classification report is as follows:")
print(classification_report(Y_test, y_test_pred))
# Out:
# Confusion Matrix - Training Data:
#  [[288  55]
#  [ 70 124]]
# Confusion Matrix - Test Data:
#  [[138  19]
#  [ 36  38]]
# Accuracy on the training set: 0.767
# Accuracy on the test set: 0.762
# The classification report is as follows:
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83       157
#            1       0.67      0.51      0.58        74
#
#     accuracy                           0.76       231
#    macro avg       0.73      0.70      0.71       231
# weighted avg       0.75      0.76      0.75       231
